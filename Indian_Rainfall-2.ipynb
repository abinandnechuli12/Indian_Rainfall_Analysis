# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('rainfaLLIndia.csv')

# %%
df.head()
# Out:
#                 subdivision  YEAR    JUN    JUL    AUG    SEP  JUN-SEP
# 0  ANDAMAN & NICOBAR ISLAND  1901  517.5  365.1  481.1  332.6   1696.3
# 1  ANDAMAN & NICOBAR ISLAND  1902  537.1  228.9  753.7  666.2   2185.9
# 2  ANDAMAN & NICOBAR ISLAND  1903  479.9  728.4  326.7  339.0   1874.0
# 3  ANDAMAN & NICOBAR ISLAND  1904  495.1  502.0  160.1  820.4   1977.6
# 4  ANDAMAN & NICOBAR ISLAND  1905  628.7  368.7  330.5  297.0   1624.9

# %%
df.shape
# Out:
# (4332, 7)

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# subdivision    0
# YEAR           0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# JUN-SEP        0
# dtype: int64

# %%
df.groupby(['YEAR', 'subdivision']).sum()
# Out:
#                                        JUN    JUL    AUG    SEP  JUN-SEP
# YEAR subdivision
# 1901 ANDAMAN & NICOBAR ISLAND        517.5  365.1  481.1  332.6   1696.3
#      ASSAM & MEGHALAYA               527.9  431.7  464.9  293.1   1717.6
#      BIHAR                            68.2  246.4  319.6  154.8    789.0
#      CHATHISGARH                     129.9  346.5  358.7  214.1   1049.2
#      COASTAL ANDHRA PRADESH & YANAM   64.8  107.2  118.7  113.7    404.4
# ...                                    ...    ...    ...    ...      ...
# 2021 UTTARANCHAL                     262.9  371.6  307.6  214.0   1156.1
#      VIDARBHA                        203.5  293.3  174.8  296.8    968.4
#      WEST MADHYA PRADESH             133.9  289.4  302.3  247.5    973.1
#      WEST RAJASTHAN                   50.2   80.7   38.3  148.4    317.5
#      WEST UTTAR PRADESH               73.5  234.6  149.8  130.3    588.3
#
# [4332 rows x 5 columns]

# %%
len(df.subdivision.unique())
# Out:
# 36

# %%
df.columns
# Out:
# Index(['subdivision', 'YEAR', 'JUN', 'JUL', 'AUG', 'SEP', 'JUN-SEP'], dtype='object')

# %% [markdown]
# ### Amount Of Rainfall

# %%
df.groupby('subdivision')['JUN', 'JUL', 'AUG', 'SEP'].sum().plot(kind = 'bar', figsize = (15, 4), title='RainFall', xlabel = 'States', ylabel = 'Amount');

# %% [markdown]
# ### Amount Of Rainfall in different years

# %%
df.groupby('YEAR')['JUN-SEP'].sum().plot(kind = 'barh', figsize = (15, 19), title='RainFall', xlabel = 'States', ylabel = 'Amount');
